# %% [markdown]
# # PyTorch MNIST – Complete Tutorial

# %% [markdown]
# ## 1-Set Up Your Environment

# %% [markdown]
# Before we start coding, we need to set up our environment with the necessary packages:

# %%
# !pip install torch torchvision matplotlib
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: torchvision in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (0.27.0)
# Requirement already satisfied: matplotlib in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (3.10.9)
# Requirement already satisfied: filelock in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (2026.6.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (3.7.0)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (1.15.1.6)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.0.4.66)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.0.0.61)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (10.4.0.35)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.96)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.6.3.3)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-bindings<14,>=13.0.3->torch) (1.5.5)
# Requirement already satisfied: numpy in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pyparsing>=3 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: torch in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: torchvision in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (0.27.0)
# Requirement already satisfied: filelock in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (2026.6.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torch) (3.7.0)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.0.4.66)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.96)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (10.4.0.35)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (1.15.1.6)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.0.0.61)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.6.3.3)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from cuda-bindings<14,>=13.0.3->torch) (1.5.5)
# Requirement already satisfied: numpy in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/xji650/workspace/tfg/tfg-systemd-kubernetes/.venv/lib/python3.10/site-packages (from jinja2->torch) (3.0.3)

# %%
import os
import json
from datetime import datetime  # <-- NUEVO: Para la hora del experimento
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt

# %% [markdown]
# For this tutorial, you’ll need PyTorch and torchvision installed. If you don’t have them yet, you can install them using pip:

# %% [markdown]
# ## 2 – Load and Prepare the MNIST Dataset

# %% [markdown]
# MNIST contains 60,000 training images and 10,000 test images of handwritten digits (0-9). Here’s how to load and prepare the dataset:

# %%
# Define transformations for the images
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert images to PyTorch tensors
    transforms.Normalize((0.1307,), (0.3081,))  # Normalize with MNIST mean and std
])

# Load the training dataset
train_dataset = torchvision.datasets.MNIST(
    root='./data',  # Where to store the dataset
    train=True,     # This is training data
    download=True,  # Download if not present
    transform=transform  # Apply transformations
)

# Load the test dataset
test_dataset = torchvision.datasets.MNIST(
    root='./data',
    train=False,
    download=True,
    transform=transform
)

# Create data loaders for batch processing
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# Let’s visualize some of the images to get a feel for the data:

# %%
# Function to display images
def show_images(images, labels):
    fig, axes = plt.subplots(2, 5, figsize=(10, 4))
    axes = axes.flatten()

    for i in range(10):
        axes[i].imshow(images[i].reshape(28, 28), cmap='gray')
        axes[i].set_title(f"Label: {labels[i]}")
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

# Get some random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

# Show images
show_images(images[:10], labels[:10])

# %% [markdown]
# Create a validation set:

# %%
# Define the size of the sets
train_size = int(0.8 * len(train_dataset)) # 80% for training
val_size = len(train_dataset) - train_size # 20% for validation

# Split the dataset
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# Create new loaders
train_loader = DataLoader(train_subset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=64, shuffle=False)

print(f"Training set size: {len(train_subset)}")
print(f"Validation set size: {len(val_subset)}")
# Out:
# Training set size: 48000
# Validation set size: 12000

# %% [markdown]
# ## 3 – Create a Neural Network Model CNN

# %% [markdown]
# Simple neural network (MLP) works reasonably well, convolutional neural networks (CNNs) are typically better for image processing tasks:

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(2, 2)
        # Añadimos Dropout aquí
        self.dropout = nn.Dropout(0.25) 
        
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.dropout(x) # Aplicamos dropout
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(-1, 64 * 7 * 7)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Initialize the CNN model
model = CNN()
print(model)
# Out:
# CNN(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.25, inplace=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=3136, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# ## 4 – Train the Neural Network

# %% [markdown]
# Create folders to store the experiments

# %%
# Create a directory for the experiment with a timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
exp_dir = f"experiments/exp_{timestamp}"
os.makedirs(exp_dir, exist_ok=True)
print(f" New experiment created in: {exp_dir}")

best_model_path = os.path.join(exp_dir, 'best_model.pth')
# Out:
#  New experiment created in: experiments/exp-20260618-164112

# %% [markdown]
# Here’s how to train the neural network:

# %%
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)

# Training and Validation loop
num_epochs = 5
train_losses = [] 
val_losses = []
best_val_loss = float('inf') 

for epoch in range(num_epochs):
    # --- TRAINING PHASE ---
    model.train() 
    running_loss = 0.0

    for i, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    # Calculate average training loss for the epoch
    epoch_train_loss = running_loss / len(train_loader)
    train_losses.append(epoch_train_loss) # Ensure list is updated

    # --- VALIDATION PHASE ---
    model.eval() 
    val_loss = 0.0
    
    with torch.no_grad(): 
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
    
    avg_val_loss = val_loss / len(val_loader)
    val_losses.append(avg_val_loss) # Ensure list is updated
    
    print(f'Epoch [{epoch+1}/{num_epochs}] | Train Loss: {epoch_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}')

    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), best_model_path)
        print(f"-> New best model saved in {best_model_path}!")

print('Training finished!')
# Out:
# Using device: cpu
# Epoch [1/5] | Train Loss: 0.2451 | Val Loss: 0.0759
# -> New best model saved in experiments/exp-20260618-164112/best_model.pth!
# Epoch [2/5] | Train Loss: 0.0663 | Val Loss: 0.0495
# -> New best model saved in experiments/exp-20260618-164112/best_model.pth!
# Epoch [3/5] | Train Loss: 0.0467 | Val Loss: 0.0501
# Epoch [4/5] | Train Loss: 0.0349 | Val Loss: 0.0405
# -> New best model saved in experiments/exp-20260618-164112/best_model.pth!
# Epoch [5/5] | Train Loss: 0.0290 | Val Loss: 0.0403
# -> New best model saved in experiments/exp-20260618-164112/best_model.pth!
# Training finished!

# %% [markdown]
# I find it helpful to visualize the training process by plotting the loss:

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss') # Opcional: ver ambas comparadas
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plot_path = os.path.join(exp_dir, 'loss-curve.png')
plt.savefig(plot_path)

plt.show()

# %% [markdown]
# ## 5 – Evaluate the Model

# %% [markdown]
# After training, we need to evaluate how well our model performs on unseen data:

# %%
model.load_state_dict(torch.load(best_model_path, map_location=device))

# Evaluate the model
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy on the test set: {accuracy:.2f}%')
# Out:
# Accuracy on the test set: 99.09%

# %% [markdown]
# Store benchmark in json format

# %%
metrics = {
    "timestamp": timestamp,
    "epochs_trained": num_epochs,
    "final_train_loss": train_losses[-1],
    "best_val_loss": best_val_loss,
    "test_accuracy": accuracy,
    "model_file": "best_model.pth"
}

metrics_path = os.path.join(exp_dir, 'metrics.json')
with open(metrics_path, 'w') as f:
    json.dump(metrics, f, indent=4)

print(f" Benchmarks stored in: {metrics_path}")
# Out:
#  Benchmarks stored in: experiments/exp-20260618-164112/metrics.json

# %% [markdown]
# Let’s visualize some predictions to see how our model is doing:

# %%
# Function to show predictions
def show_predictions(images, labels, preds):
    fig, axes = plt.subplots(2, 5, figsize=(10, 4))
    axes = axes.flatten()

    for i in range(10):
        axes[i].imshow(images[i].cpu().reshape(28, 28), cmap='gray')
        color = 'green' if preds[i] == labels[i] else 'red'
        axes[i].set_title(f"Pred: {preds[i]}, True: {labels[i]}", color=color)
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

# Get predictions for some test images
dataiter = iter(test_loader)
images, labels = next(dataiter)
images, labels = images.to(device), labels.to(device)

outputs = model(images)
_, preds = torch.max(outputs, 1)

# Select 10 random indices from the batch
random_indices = random.sample(range(images.size(0)), 10)

random_images = images[random_indices]
random_labels = labels[random_indices]
random_preds = preds[random_indices]

# Show predictions
show_predictions(random_images, random_labels, random_preds)

# %% [markdown]
# ## 6 – Save and Load Your Model

# %% [markdown]
# It’s good practice to save your trained model so you can use it later without retraining:

# %%
# Save the model
torch.save(model.state_dict(), 'mnist_model.pth')
print("Model saved!")

# Load the model (for future use)
loaded_model = CNN()
loaded_model.load_state_dict(torch.load('mnist_model.pth'))
loaded_model.to(device)
loaded_model.eval()
print("Model loaded!")
# Out:
# Model saved!
# Model loaded!
